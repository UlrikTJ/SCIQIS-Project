# %% [markdown]
# # Slide 1

# %%
# !which python
# Out:
# /home/jsne/src/sciqis/.venv/bin/python

# %%
import numpy as np

# %% [markdown]
# ## Slide 1a
#
# This works

# %%
4+7
# Out:
# 11

# %%
numpy.exp(.3)
# Out:
# np.float64(1.3498588075760032)

# %%
7-6
# Out:
# 1
